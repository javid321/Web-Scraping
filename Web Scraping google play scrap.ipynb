# %%
#references : https://www.youtube.com/watch?v=-QUyD0YFYb0&ab_channel=HDMVision

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app
from google_play_scraper import Sort, reviews_all

# %%
#scrape semua review
reviews = reviews_all(
    '',
    sleep_milliseconds =0,
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST
)

# %%
#scrape sejumlah review
from google_play_scraper import Sort, reviews
result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 200,
    filter_score_with = None
)

# %%
# rev_df = pd.DataFrame(result)
# rev_df

# %%
rev_df = pd.DataFrame(np.array(result), columns=['review'])
rev_df = rev_df.join(pd.DataFrame(rev_df.pop('review').tolist()))
# rev_df = pd.DataFrame(rev_df['review'].tolist())
rev_df
# Out:
#                                  reviewId          userName  \
# 0    5e1dfd7a-a27e-4358-80d0-72fd5f96d0c9      yuuki hikaru
# 1    b7af7ee2-c754-40ea-9115-43119f8efa45         Apri Yadi
# 2    abe76cc0-a68f-4030-85d0-a9c08ab6e7d3       Eki Nugraha
# 3    4c91af54-b78f-4747-b5cd-fe4f30a72c2c       Erika ystnn
# 4    1e9e2f7a-3bdb-4a69-935d-b9aa22a61bce             prast
# ..                                    ...               ...
# 195  d6bbf65d-8a91-43c8-a2b3-736493a70e62    Ridha Al Qadri
# 196  561a5349-bf5e-4898-bb25-6cf64ea82c90    muhamad ismail
# 197  881679e9-c421-4980-972d-364e61c3091e           Arif Xc
# 198  aae598f8-c373-49df-8fc7-6087f0ce04a8          Fredi Fu
# 199  1a2349f2-6f90-40c3-9ff4-b6875e22c204  Dhavied Aprillia
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/AGNmyx...
# 1    https://play-lh.googleusercontent.com/a/AGNmyx...
# 2    https://play-lh.googleusercontent.com/a/AGNmyx...
# ...

# %%
rev_df.shape
# Out:
# (200, 10)

# %%
review_df = rev_df[['userName', 'content', 'score', 'at']]

# %%
review_df
# Out:
#              userName                                            content  \
# 0        yuuki hikaru  Keputusan sepihak tanpa mendengar penjelasan user
# 1           Apri Yadi             Tokopedia bsa ambil dlu byar nanti oke
# 2         Eki Nugraha                                  Mantap barang ori
# 3         Erika ystnn  Pengiriman dengan ANTERAJA parah ga sampe samp...
# 4               prast  TOKO JUAL BELI ONLINE PALING BRENGSEK. HATI HA...
# ..                ...                                                ...
# 195    Ridha Al Qadri                               Kode Error (OO-ZJBN)
# 196    muhamad ismail        Membantu memberikan layanan untuk berdagang
# 197           Arif Xc                                               Good
# 198          Fredi Fu                                             Mantap
# 199  Dhavied Aprillia                                              Jelek
#
#      score                  at
# 0        1 2023-03-12 13:43:56
# ...

# %%
review_df.shape
# Out:
# (200, 4)

# %%
review_nlp = rev_df[['content', 'score']]

# %%
review_nlp
# Out:
#                                                content  score
# 0    Keputusan sepihak tanpa mendengar penjelasan user      1
# 1               Tokopedia bsa ambil dlu byar nanti oke      4
# 2                                    Mantap barang ori      5
# 3    Pengiriman dengan ANTERAJA parah ga sampe samp...      1
# 4    TOKO JUAL BELI ONLINE PALING BRENGSEK. HATI HA...      1
# ..                                                 ...    ...
# 195                               Kode Error (OO-ZJBN)      5
# 196        Membantu memberikan layanan untuk berdagang      5
# 197                                               Good      5
# 198                                             Mantap      5
# 199                                              Jelek      1
#
# [200 rows x 2 columns]

# %%
review_nlp.to_csv('review_tokped.csv', index=False)

# %%
df = pd.read_csv('./review_tokped.csv')
df
# Out:
#                                                content  score
# 0    Keputusan sepihak tanpa mendengar penjelasan user      1
# 1               Tokopedia bsa ambil dlu byar nanti oke      4
# 2                                    Mantap barang ori      5
# 3    Pengiriman dengan ANTERAJA parah ga sampe samp...      1
# 4    TOKO JUAL BELI ONLINE PALING BRENGSEK. HATI HA...      1
# ..                                                 ...    ...
# 195                               Kode Error (OO-ZJBN)      5
# 196        Membantu memberikan layanan untuk berdagang      5
# 197                                               Good      5
# 198                                             Mantap      5
# 199                                              Jelek      1
#
# [200 rows x 2 columns]
